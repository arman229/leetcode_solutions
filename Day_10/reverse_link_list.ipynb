# %% [markdown]
# ## 206. Reverse Linked List
#
# ---
#
# Given the `head` of a singly linked list, reverse the list and return the reversed list.
#
# ---
#
# ### Example 1
#
# **Input:**
# ```text
# head = [1,2,3,4,5]
# ````
#
# **Output:**
#
# ```text
# [5,4,3,2,1]
# ```
#
# ---
#
# ### Example 2
#
# **Input:**
#
# ```text
# head = [1,2]
# ```
#
# **Output:**
#
# ```text
# [2,1]
# ```
#
# ---
#
# ### Example 3
#
# **Input:**
#
# ```text
# head = []
# ```
#
# **Output:**
#
# ```text
# []
# ```
#
# ---
#
# ### Constraints
#
# * The number of nodes in the list is in the range `[0, 5000]`
# * `-5000 <= Node.val <= 5000`
#
# ---
#
# ### Follow-up
#
# A linked list can be reversed either **iteratively** or **recursively**.
# Could you implement both?
#
# ```
# ```

# %%
from typing import Optional

# %%
# Efficient solution with O(n) time complexity and O(1) space complexity
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        cur_node,prev_node = head,None
        while cur_node:
            nex_node = cur_node.next
            cur_node.next = prev_node
            prev_node = cur_node
            cur_node = nex_node
        return prev_node

# %% [markdown]
# ### Complexity Analysis
# - Time Complexity: O(N)
# - Space Complexity: O(1)

# %%
# Not Efficient solution with O(n) time complexity and O(n) space complexity
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head or not head.next:
            return head
        new_head = self.reverseList(head.next)
        head.next.next = head
        head.next = None
        return new_head

# %% [markdown]
# ### Complexity Analysis
# - Time Complexity: O(N)
# - Space Complexity: O(N)
