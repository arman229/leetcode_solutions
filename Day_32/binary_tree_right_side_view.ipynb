# %% [markdown]
#
# # 199. Binary Tree Right Side View
#
# Given the `root` of a binary tree, imagine yourself standing on the **right side** of it. Return *the values of the nodes you can see ordered from top to bottom*.
#
# ---
#
# ## Example 1
#
# **Input:**
#
# ```text
# root = [1,2,3,null,5,null,4]
# ````
#
# **Output:**
#
# ```text
# [1,3,4]
# ```
#
# **Explanation:**
#
# ![Binary Tree Right Side View](https://assets.leetcode.com/uploads/2024/11/24/tmpd5jn43fs-1.png)
#
# ---
#
# ## Example 2
#
# **Input:**
#
# ```text
# root = [1,2,3,4,null,null,null,5]
# ```
#
# **Output:**
#
# ```text
# [1,3,4,5]
# ```
#
# **Explanation:**
#
# ![Binary Tree Right Side View](https://assets.leetcode.com/uploads/2024/11/24/tmpkpe40xeh-1.png)
#
# ---
#
# ## Example 3
#
# **Input:**
#
# ```text
# root = [1,null,3]
# ```
#
# **Output:**
#
# ```text
# [1,3]
# ```
#
# ---
#
# ## Example 4
#
# **Input:**
#
# ```text
# root = []
# ```
#
# **Output:**
#
# ```text
# []
# ```
#
# ---
#
# ## Constraints
#
# * The number of nodes in the tree is in the range `[0, 100]`.
# * `-100 <= Node.val <= 100`
#
# ```

# %%
# Definition for a binary tree node.
from collections import deque
from typing import List, Optional
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        if not root:
            return []
        queue = deque([root])
        res = []
        while queue:
            level = len(queue)
            for i in range(level):
                node = queue.popleft()
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
                if i == level -1:
                    res.append(node.val)
        return res

# %% [markdown]
# ### Complexity Analysis
# - Time Complexity: O(n)
# - Space Complexity: O(n)
